# %%
HF_KEY = 'hsdfsddsfgdsf'  # replace with your own token: huggingface.co/settings/tokens
GROQ_API_KEY = 'gsk_dfjdkfng'

# %% [markdown]
# # Groq to use Llama3

# %%
from groq import Groq

client = Groq(
    api_key= GROQ_API_KEY
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content":  "What is the capital of France?"
        }
    ],
    model="meta-llama/llama-4-maverick-17b-128e-instruct",
)

print(chat_completion.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# # Using Inference with [Together AI](https://together.ai/) to use DeepSeek R1

# %%
import huggingface_hub; huggingface_hub.__version__
# Out:
# '0.33.2'

# %%
from huggingface_hub import InferenceClient

together_client = InferenceClient(
	provider="together",
	api_key=HF_KEY
)

messages = [
	{
		"role": "user",
		"content": "What is the capital of France?"
	}
]

completion = together_client.chat.completions.create(
    model="deepseek-ai/DeepSeek-R1", 
	messages=messages, 
	max_tokens=1024,
)

# %%
print(completion.choices[0].message.content)
# Out:
# <think>
# Okay, the user is asking about the capital of France. That's a straightforward geography question.
#
# Hmm, this seems like a very basic fact - almost everyone knows Paris is the capital. Maybe the user is a young student just starting to learn about countries? Or perhaps they're double-checking for some reason?
#
# I should keep the answer simple and clear. No need for extra details unless they ask follow-ups. The response should be accurate but friendly - no point making them feel silly for asking a simple question.
#
# The emoji might help make it feel more approachable. A flag and landmark would visually reinforce the answer too.
#
# Better confirm the spelling is correct - "Paris" not "Paries". And yep, France's capital hasn't changed in modern history.
#
# Just the facts then: city name, country, and two recognizable symbols. Short and sweet.
# </think>
# The capital of France is **Paris**. 🇫🇷🗼
#
# It is the country's largest city and a major global center for art, fashion, gastronomy, and culture.

# %%
together_client
# Out:
# <InferenceClient(model='', timeout=None)>

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(
	# provider="together",  without together yields error because HF itself doesn't have an inference endpoint for this model 
	api_key=HF_KEY
)
completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-R1", 
	messages=messages, 
	max_tokens=1024,
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /opt/homebrew/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://router.huggingface.co/together/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[8], line 7
#       1 from huggingface_hub import InferenceClient
#       3 client = InferenceClient(
#       4 	# provider="together",  without together yields error because HF itself doesn't have an inference endpoint for this model
#       5 	api_key=HF_KEY
#       6 )
# ----> 7 completion = client.chat.completions.create(
#       8     model="deepseek-ai/DeepSeek-R1",
#       9 	messages=messages,
#      10 	max_tokens=1024,
#      11 )
#
# File /opt/homebrew/lib/python3.13/site-packages/huggingface_hub/inference/_client.py:924, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     896 parameters = {
#     897     "model": payload_model,
#     898     "frequency_penalty": frequency_penalty,
#    (...)
#     915     **(extra_body or {}),
#     916 }
#     917 request_parameters = provider_helper.prepare_request(
#     918     inputs=messages,
#     919     parameters=parameters,
#    (...)
#     922     api_key=self.token,
#     923 )
# --> 924 data = self._inner_post(request_parameters, stream=stream)
#     926 if stream:
#     927     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File /opt/homebrew/lib/python3.13/site-packages/huggingface_hub/inference/_client.py:280, in InferenceClient._inner_post(self, request_parameters, stream)
#     277         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     279 try:
# --> 280     hf_raise_for_status(response)
#     281     return response.iter_lines() if stream else response.content
#     282 except HTTPError as error:
#
# File /opt/homebrew/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     478     raise _format(HfHubHTTPError, message, response) from e
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 429 Client Error: Too Many Requests for url: https://router.huggingface.co/together/v1/chat/completions (Request ID: oHwe9je-28Eivz-9996135a9e38ee0d)
#
# {'message': 'You are on tier Build Tier 1, which offers 3 queries and 180000 tokens per minute for this model. Please upgrade to higher tier for higher rate limit at https://api.together.ai/settings/billing.', 'type': 'model_rate_limit', 'param': None, 'code': None}

# %%
# Using Cohere as an inference provider: https://huggingface.co/blog/inference-providers-cohere

cohere_hf_client = InferenceClient(
    provider="cohere",
    api_key=HF_KEY,
)
# https://huggingface.co/CohereLabs/c4ai-command-a-03-2025
completion = cohere_hf_client.chat.completions.create(
    model="CohereLabs/c4ai-command-a-03-2025",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    max_tokens=512,
)

print(completion.choices[0].message.content)
# Out:
# The capital of France is **Paris**. It is the country's largest city and main cultural and commercial center, known for landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral.

# %% [markdown]
# # VQA Using Qwen

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="nebius",
    api_key=HF_KEY,
)

completion = client.chat.completions.create(
    model="Qwen/Qwen2.5-VL-72B-Instruct",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Describe this image in one sentence."
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://cdn.britannica.com/61/93061-050-99147DCE/Statue-of-Liberty-Island-New-York-Bay.jpg"
                    }
                }
            ]
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionOutputMessage(role='assistant', content='The Statue of Liberty stands majestically on Liberty Island, with the iconic New York City skyline as its backdrop across the water.', tool_call_id=None, tool_calls=[], refusal=None, annotations=None, audio=None, function_call=None, reasoning_content=None)
